# %%
d={'name':['A'],'password':['abcd'],'init_bal':[10000],'acc_no':[1001]}

# %%
def home():
    print("WELCOME to BANK!!!".center(100,"*"))
    print("\n")
    print("1.LOG-IN".center(100))
    print("\n")
    print("2.SIGN-IN".center(100))
    print("\n")
    print("3.EXIT".center(100))
    ch=int(input("Enter your choice:"))
    return ch
def chk_acc(acc):
    if acc in d['acc_no']:
        i=d['acc_no'].index(acc)
        __import__('os').system("reset")
        password=input("Enter password:")
        ch=chk_pass(password,i)
        if ch=='y':
            return 2
        else:
            return 3
        return 0
    else:
        return 1
def chk_pass(password,i):
    if password==d['password'][i]:
            __import__('os').system("reset")
            print("\n")
            return 'y'
    else:
        return 'n'
def choices():
    print("\n")
    print("CHOICES".center(100,"*"))
    print("\n")
    print("\n")
    print("1.DEBIT".center(100))
    print("\n")
    print("2.CREDIT".center(100))
    print("\n")
    print("3.CHECK_BALANCE".center(100))
    print("\n")
    print("4.Change password".center(100))
    print("\n")
    print("5.EXIT".center(100))
    n=int(input("Enter your CHOICE:"))
    return n

# %%
import os
ch=home()
__import__('os').system("reset")
while ch!=3:
    if ch==1:
        print("\n")
        acc=int(input("Enter account_number:"))
        cho=chk_acc(acc)
        while cho!=2:
            if cho==1:
                print("\n")
                print("Sorry incorrect account no")
                ch=home()
                break
            elif ch==3:
                print("\n")
                __import__('os').system("reset")
                print("Your password is in correct ....check again!!!!!!!")
                ch=home()
                break
                
        else:
            n=choices()
            while n!=5:
  
        print("\nAccount Created Sucessfully  ")
        print("\nyour Account Number  is : {} ".format(acc))
        __import__('os').system("reset")
        ch=home()
    elif ch==3:
        pass
    else:
        print("Invalid input")
        ch=home()
else:
    print("\n")
    print("You are out!!!")
    print("Thanks for visiting us..........")
    print("\n")
        
        
              i=d['acc_no'].index(acc)
                if n==1:
                    amt=int(input("Enter amount:"))
                    if amt>d['init_bal'][i]:
                        print("Your account has {} this much balance go wisely!!!".format(d['init_bal'][i]))
                        n=choices()
                    else:
                        d['init_bal'][i]-=amt
                        print("Your current balance is:{}".format(d['init_bal'][i]))
                        n=choices()
                elif n==2:
                    amt=float(input("Enter amount:"))
                    d['init_bal'][i]+=amt
                    print("Your current balance is:{}".format(d['init_bal'][i]))
                    n=choices()
                elif n==3:
                    print("Your current balance is:{}".format(d['init_bal'][i]))
                    n=choices()
                elif n==4:
                    pswd=input("Enter your new password:")
                    d['password'][i]=pswd
                    print("Your password is changed")
                    n=choices()
            else:
                ch=home()
    elif ch==2:
        name = input("\n\nEnter name : ")
        __import__('os').system("reset")
        password = input("Enter password : ")
        __import__('os').system("reset")
        bal = int(input("Enter balance to deposit : "))
        __import__('os').system("reset")
        acc = d['acc_no'][-1] + 1
        d['name'].append(name)
        d['password'].append(password)
        d['init_bal'].append(bal)
        d['acc_no'].append(acc)
        print("\n")
# Out:
# *****************************************WELCOME to BANK!!!*****************************************
#
#
#                                               1.LOG-IN
#
#
#                                              2.SIGN-IN
#
#
#                                                3.EXIT
# Enter your choice:2
#
#
# Enter name : 1002
# Enter password : cdf01f2
# Enter balance to deposit : 20000
#
#
#
# Account Created Sucessfully
#
# your Account Number  is : 1002
# *****************************************WELCOME to BANK!!!*****************************************
#
#
#                                               1.LOG-IN
#
#
#                                              2.SIGN-IN
#
#
#                                                3.EXIT
# Enter your choice:1
#
#
# Enter account_number:1002
# Enter password:cdf01f2
#
#
#
#
# **********************************************CHOICES***********************************************
#
#
#
#
# ...
