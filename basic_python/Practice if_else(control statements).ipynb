# %%
#1) Greatest b/w two numbers

x=int(input("Enter first number:"))
y=int(input("Enter second number:"))
if x>y:
    print("{} is greater".format(x))
else:
    print("{} is greater".format(y))
# Out:
# Enter first number:3
# Enter second number:3
# 3 is greater

# %%
#2) Greatest b/w 3 numbers

x=int(input("Enter a number(x):"))
y=int(input("Enter a number(y):"))
z=int(input("Enter a number(z):"))
if x>=y and x>=z:
    print("{} is greatest".format(x))
elif y>=x and y>=z:
    print("{} is greatest".format(y))
else:
    print("{} is greatest".format(z))
# Out:
# Enter a number(x):3
# Enter a number(y):3
# Enter a number(z):4
# 4 is greatest

# %%
#3) Check positive,negative or zero

x=int(input("Enter a number:"))
if x>0:
    print("Positive")
elif x<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number:-678
# Negative

# %%
#4) number divisible by 5 and 11 or not

x=int(input("Enter a number:"))
if not(x%5) and not(x%11):
    print("Number is divisible by both")
elif not(x%5) and x%11:
    print("Number is divisible by 5 only")
elif x%5 and not(x%11):
    print("Number is divisible by 11 only")
else:
    print("Not divisible")
# Out:
# Enter a number:15
# Number is divisible by 5 only

# %%
#5) Even odd
num=int(input("Enter a Number:"))
if num%2:
    print("Odd")
else:
    print("Even")
# Out:
# Enter a Number:34
# Even

# %%
#6) Leap year

x=int(input("Enter any year:"))
year=x
if(year%100 and year%4==0 ) or (year%400==0):
    print("Leap Year")
else:
    print("Not a leap year")
# Out:
# Enter any year:1900
# Not a leap year

# %%
#7) alphabet or not

x=input("Enter a character:")
if len(x)==1 and x.isalpha():
    print("Yes")
else:
    print("NO")
# Out:
# Enter a character:@
# NO

# %%
#8) Vowel and consonant

x=input("Enter a character:").lower()
l = ['a','e','i','o','u']
if len(x)==1:
    if x in l:
        print("Vowel")
    else:
        print("Consonent")
else:
    print("Invalid input")
# Out:
# Enter a character:e
# Vowel

# %%
#9) check whether it is alphabet, digit or special character.


x=input("Enter a character:")
if len(x)==1:
    if x.isalpha():
        print("Alphabet")
    elif x.isdigit():
        print("DIGIT")
    else:
        print("Special character")
else:
    print("Invalid input")
# Out:
# Enter a character:d
# Alphabet

# %%
# 10)a character is uppercase or lowercase alphabet.

x=input("Enter a character:")
if len(x)==1 and x.isalpha():
    if x.islower():
        print("LOWER")
    elif x.upper():
        print("UPPER")
else:
    print("Invalid input")
# Out:
# Enter a character:A
# UPPER

# %%
# 11)
l=['Monday','Tuesday','Wednesday','Thrusday','Friday','saturday','sunday']
x=int(input("Enter a week number:"))
print(l[x-1])
# Out:
# Enter a week number:3
# Wednesday

# %%
# 12)to input month number and print number of days in that month.


l=['jan','feb','mar','apr','may','june','july','august','sept','oct','nov','dec']
num=int(input("Enter month:"))
if num>=1  and num<=12:
    print(l[num-1])
else:
    print("Invalid input")
# Out:
# Enter month:11
# nov

# %%
# 13) to count notes in given amount of money

amt=int(input("Enter amount to count notes:"))
d={}
l=[2000,500,200,100,50,20,10,5,2,1]
for i in l:
    if amt>=i:
        d[i]=amt//i
        amt-=d[i]*i
print("Total notes req:",d)
# Out:
# Enter amount to count notes:3991
# Total notes req: {2000: 1, 500: 3, 200: 2, 50: 1, 20: 2, 1: 1}

# %%
# 14) Triangle or not(by side):

x=int(input("Enter a side:"))
y=int(input("Enter a side:"))
z=int(input("Enter a side:"))
if x>y+z or y>x+z or z>x+y:
    print("Triangle")
else:
    print("Not triangle")
# Out:
# Enter a side:4
# Enter a side:5
# Enter a side:78
# Triangle

# %%
# 15) Triangle or not(by Angles):

x=int(input("Enter a angle of side:"))
y=int(input("Enter a angle of side:"))
z=int(input("Enter a angle of side:"))
if x+y+z==180:
    print("Triangle")
else:
    print("Not triangle")
# Out:
# Enter a angle of side:45
# Enter a angle of side:45
# Enter a angle of side:90
# Triangle

# %%
# 16)which triangle(equilateral,scalene,isosceles)

x=int(input("Enter a side:"))
y=int(input("Enter a side:"))
z=int(input("Enter a side:"))
if x==y and y==z:
    print("Equilateral")
elif (x==y and y!=z )or(x==z and y!=z)or (y==z and z!=x):
    print("Isosceles")
else:
    print("Scalene")
# Out:
# Enter a side:2
# Enter a side:3
# Enter a side:4
# Scalene

# %%
# 17) Finds rootsof quadratic equation

import math
a=int(input("Enter coefficient of x2:"))
b=int(input("Enter coefficient of x:"))
c=int(input("Enter coefficient of constant:"))
d=(b*b)-4*a*c;
d=math.sqrt(d)
r1=(-b+d)/2*a
r2=(-b-d)/2*a
print(r1,r2)
# Out:
# Enter coefficient of x2:1
# Enter coefficient of x:2
# Enter coefficient of constant:1
# -1.0 -1.0

# %%
# 18)Profit and loss

x=int(input("Enter cost price:"))
y=int(input("Enter sell price:"))
if(y>x):
    profit=(y-x)/x*100
    print("Profit of {}%".format(profit))
elif x>y:
    loss=(x-y)/x*100
    print("Loss of {}%".format(loss))
else:
    print("NO profit and loss")
# Out:
# Enter cost price:30
# Enter sell price:30
# NO profit and loss

# %%
## 19)Grading

l=input("Enter marks of five subject(phy/chm/math/bio/comp)")
l1=l.split()
for i in range(0,len(l1)):
    l1[i]=int(l1[i])
s=sum(l1)
s=s/5
if s>=90 and s<=100:
    print('A')
elif s>=80:
    print('B')
elif s>=70:
    print('C')
elif s>=60:
    print('D')
elif s>=40:
    print('E')
else:
    print('F')
# Out:
# Enter marks of five subject(phy/chm/math/bio/comp)90 90 90 90 90
# A

# %%
# 20)to input basic salary of an employee and calculate its Gross salary 
bs=int(input("Enter basic salary:"))
if bs<=10000:
    hra=bs*0.20
    da=bs*0.80
elif bs<=20000:
    hra=bs*0.25
    da=bs*0.90
else:
    hra=bs*0.30
    da=bs*0.95
print("Gross salary:",bs+hra+da)
# Out:
# Enter basic salary:22000
# Gross salary: 49500.0

# %%
# 21)to input electricity unit charges and calculate total electricity bill 

unit=int(input("Enter the unit charges :"))
if unit<=50:
    x=unit*0.50
elif unit<=150:
    x=unit*0.75
elif unit<=250:
    x=unit*1.20
else:
    x=unit*1.50
    x=x+(x*0.20)
print("The Electricity bill is:",x)
# Out:
# Enter the unit charges :300
# The Electricity bill is: 540.0
